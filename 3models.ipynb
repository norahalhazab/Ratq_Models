# %%
import os, numpy as np, pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.utils import class_weight
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, classification_report

import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %% [markdown]
# # Cell 2 — TensorFlow Configuration (GPU, Precision, XLA)

# %%
print("TF version:", tf.__version__)
print("GPUs:", tf.config.list_physical_devices("GPU"))
print("Logical devices:", tf.config.list_logical_devices())

tf.config.optimizer.set_jit(False)   # keep OFF


# Seed
SEED = 42
tf.keras.utils.set_random_seed(SEED)
# Out:
# TF version: 2.10.1
# GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Logical devices: [LogicalDevice(name='/device:CPU:0', device_type='CPU'), LogicalDevice(name='/device:GPU:0', device_type='GPU')]

# %%
print("TF version:", tf.__version__)
print("GPUs:", tf.config.list_physical_devices("GPU"))
# Out:
# TF version: 2.10.1
# GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
from tensorflow.keras import mixed_precision
mixed_precision.set_global_policy("float32")
print("Policy:", mixed_precision.global_policy())
# Out:
# Policy: <Policy "float32">

# %% [markdown]
# # Cell 3 -Load CSV Flies

# %%
# ✅ Train on augmented images
TRAIN_DIR = "SurgWound_Augmented"
TRAIN_CSV = os.path.join(TRAIN_DIR, "train_aug_data.csv")

# ✅ Validate/Test on clean images
CLEAN_DIR = "SurgWound_Cleaned"
VAL_CSV   = os.path.join(CLEAN_DIR, "validation_data.csv")
TEST_CSV  = os.path.join(CLEAN_DIR, "test_data.csv")

assert os.path.exists(TRAIN_CSV), "Missing train_aug_data.csv"
assert os.path.exists(VAL_CSV), "Missing validation_data.csv"
assert os.path.exists(TEST_CSV), "Missing test_data.csv"
print("✅ CSVs found")
# Out:
# ✅ CSVs found

# %% [markdown]
# #  Cell 4 — Load & Filter Erythema Samples

# %%
def load_task(df, task_key="erythema"):
    df = df.copy()
    df = df[df["image_id"].astype(str).str.contains(task_key, case=False, na=False)]
    df = df[df["answer"].astype(str).str.lower() != "uncertain"]
    df["answer"] = df["answer"].astype(str).str.strip()
    df["filename"] = (
        df["filename"].astype(str)
        .str.replace("\\\\", "/", regex=False)
        .str.replace("\\", "/", regex=False)
    )
    return df.reset_index(drop=True)

train_df = load_task(pd.read_csv(TRAIN_CSV), "erythema")
val_df   = load_task(pd.read_csv(VAL_CSV),   "erythema")
test_df  = load_task(pd.read_csv(TEST_CSV),  "erythema")

print("Train:\n", train_df["answer"].value_counts())
print("Val:\n", val_df["answer"].value_counts())
print("Test:\n", test_df["answer"].value_counts())
# Out:
# Train:
#  answer
# Non-existent    2004
# Existent         774
# Name: count, dtype: int64
# Val:
#  answer
# Non-existent    44
# Existent        22
# Name: count, dtype: int64
# Test:
#  answer
# Non-existent    91
# Existent        40
# Name: count, dtype: int64

# %% [markdown]
# # Cell 5 — Dataset Sanity Check

# %%
p = os.path.join(TRAIN_DIR, train_df["filename"].iloc[0])
print("Example train file:", train_df["filename"].iloc[0])
print("Exists?", os.path.exists(p))
assert os.path.exists(p), "❌ Train augmented image path mismatch."
print("✅ Paths OK")
# Out:
# Example train file: train/images/0.jpg_erythema.jpg
# Exists? True
# ✅ Paths OK

# %% [markdown]
# # Cell 6 — Image Size & Data Generators

# %%
IMG_SIZE = (224, 224)
BATCH_SIZE = 4   # if still OOM -> 4

# %% [markdown]
# # Cell 7 — Class Imbalance Handling

# %%
train_datagen = ImageDataGenerator(
    brightness_range=[0.8, 1.2],
    channel_shift_range=20.0,
    rotation_range=30,
    width_shift_range=0.10,
    height_shift_range=0.10,
    zoom_range=0.20,
    horizontal_flip=True,
    fill_mode="nearest"
)

val_datagen = ImageDataGenerator()  # clean, no augmentation

train_gen = train_datagen.flow_from_dataframe(
    dataframe=train_df,
    directory=TRAIN_DIR,
    x_col="filename",
    y_col="answer",
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="sparse",
    shuffle=True,
    seed=SEED
)

val_gen = val_datagen.flow_from_dataframe(
    dataframe=val_df,
    directory=CLEAN_DIR,
    x_col="filename",
    y_col="answer",
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="sparse",
    shuffle=False
)

test_gen = val_datagen.flow_from_dataframe(
    dataframe=test_df,
    directory=CLEAN_DIR,
    x_col="filename",
    y_col="answer",
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="sparse",
    shuffle=False
)

print("✅ class_indices:", train_gen.class_indices)
NUM_CLASSES = len(train_gen.class_indices)
assert NUM_CLASSES == 2, "Expected 2 classes for erythema."
# Out:
# Found 2778 validated image filenames belonging to 2 classes.
# Found 66 validated image filenames belonging to 2 classes.
# Found 131 validated image filenames belonging to 2 classes.
# ✅ class_indices: {'Existent': 0, 'Non-existent': 1}

# %% [markdown]
# # Cell 8 — Training Utilities (Compile & Fit)

# %%
y_train = np.array(train_gen.classes, dtype=int)
classes = np.arange(NUM_CLASSES, dtype=int)

weights = class_weight.compute_class_weight(
    class_weight="balanced",
    classes=classes,
    y=y_train
)
CLASS_WEIGHTS = {int(c): float(w) for c, w in zip(classes, weights)}
print("Class weights:", CLASS_WEIGHTS)
# Out:
# Class weights: {0: 1.7945736434108528, 1: 0.6931137724550899}

# %% [markdown]
# # Cell 9,10 — Evaluation & Threshold Optimization

# %%
def freeze_bn(model):
    for l in model.layers:
        if isinstance(l, layers.BatchNormalization):
            l.trainable = False

def compile_model(model, lr, label_smoothing=0.0):
    opt = tf.keras.optimizers.Adam(learning_rate=lr)

    if label_smoothing and label_smoothing > 0:
        loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(label_smoothing=label_smoothing)
    else:
        loss_fn = "sparse_categorical_crossentropy"

    model.compile(optimizer=opt, loss=loss_fn, metrics=["accuracy"])
    return model

def fit_model(model, epochs, lr):
    compile_model(model, lr=lr)
    cbs = [
        ReduceLROnPlateau(monitor="val_loss", patience=2, factor=0.5, min_lr=1e-7, verbose=1),
        EarlyStopping(monitor="val_loss", patience=5, restore_best_weights=True, verbose=1),
    ]
    return model.fit(
        train_gen,
        validation_data=val_gen,
        epochs=epochs,
        class_weight=CLASS_WEIGHTS,
        callbacks=cbs,
        verbose=1,
        workers=1,
        use_multiprocessing=False
    )

# %%
def predict_probs(model, loader):
    probs = model.predict(loader, verbose=0)
    probs = np.array(probs)
    if probs.ndim == 1:
        probs = np.stack([1 - probs, probs], axis=1)
    return probs

def eval_on_test(model):
    probs = predict_probs(model, test_gen)
    y_pred = np.argmax(probs, axis=1)
    y_true = np.array(test_gen.classes, dtype=int)
    acc = accuracy_score(y_true, y_pred)
    f1w = f1_score(y_true, y_pred, average="weighted", zero_division=0)
    return acc, f1w, y_true, y_pred, probs

def best_threshold_on_val(model):
    probs = predict_probs(model, val_gen)
    y_val = np.array(val_gen.classes, dtype=int)

    # pick positive class index safely
    if "Existent" in train_gen.class_indices:
        ex_idx = train_gen.class_indices["Existent"]
    else:
        ex_idx = 1  # fallback: assume class 1 is positive

    p_ex = probs[:, ex_idx]
    best_t, best_f1 = 0.5, -1
    for t in np.arange(0.05, 0.96, 0.01):
        y_pred_t = np.where(p_ex >= t, ex_idx, 1 - ex_idx)
        f1w_t = f1_score(y_val, y_pred_t, average="weighted", zero_division=0)
        if f1w_t > best_f1:
            best_f1, best_t = f1w_t, t
    return float(best_t), float(best_f1)

def eval_threshold(model, t):
    probs = predict_probs(model, test_gen)
    y_true = np.array(test_gen.classes, dtype=int)

    if "Existent" in train_gen.class_indices:
        ex_idx = train_gen.class_indices["Existent"]
    else:
        ex_idx = 1

    p_ex = probs[:, ex_idx]
    y_pred = np.where(p_ex >= t, ex_idx, 1 - ex_idx)
    acc = accuracy_score(y_true, y_pred)
    f1w = f1_score(y_true, y_pred, average="weighted", zero_division=0)
    return float(acc), float(f1w), y_true, y_pred

# %% [markdown]
# # Cell 11 — Confusion Matrix Visualization

# %%
def show_confusion(y_true, y_pred, title):
    labels = {v: k for k, v in train_gen.class_indices.items()}
    class_names = [labels[i] for i in range(len(labels))]

    cm = confusion_matrix(y_true, y_pred)

    plt.figure(figsize=(5.5, 5))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
                xticklabels=class_names, yticklabels=class_names)
    plt.title(title)
    plt.xlabel("Predicted")
    plt.ylabel("True")
    plt.tight_layout()
    plt.show()

    print(classification_report(y_true, y_pred, target_names=class_names))

# %% [markdown]
# # Cell 12 — Model Architectures & Head Definition

# %%
from tensorflow.keras.applications import EfficientNetV2S, ConvNeXtTiny, ResNet101V2
from tensorflow.keras.applications.efficientnet_v2 import preprocess_input as effv2_preprocess
from tensorflow.keras.applications.convnext import preprocess_input as convnext_preprocess
from tensorflow.keras.applications.resnet_v2 import preprocess_input as resnetv2_preprocess
from tensorflow.keras.applications import EfficientNetV2M
from tensorflow.keras.applications.efficientnet_v2 import preprocess_input as effv2_preprocess

def build_head(x, num_classes=2):
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dense(512, activation="relu")(x)
    x = layers.Dropout(0.45)(x)
    x = layers.Dense(128, activation="relu")(x)
    x = layers.Dropout(0.25)(x)
    # ✅ important for mixed precision stability
    return layers.Dense(num_classes, activation="softmax", dtype="float32")(x)

def make_model(backbone_name):
    inp = tf.keras.Input(shape=(IMG_SIZE[0], IMG_SIZE[1], 3))

    if backbone_name == "ConvNeXtTiny":
        x = layers.Lambda(convnext_preprocess, name="convnext_preprocess")(inp)
        base = ConvNeXtTiny(include_top=False, weights="imagenet", include_preprocessing=False)
        feats = base(x)
        ft_last = 30

    elif backbone_name == "ResNet101V2":
        x = layers.Lambda(resnetv2_preprocess, name="resnet_preprocess")(inp)
        base = ResNet101V2(include_top=False, weights="imagenet")
        feats = base(x)
        ft_last = 90

    elif backbone_name == "EfficientNetV2S":
        x = layers.Lambda(effv2_preprocess, name="effv2_preprocess")(inp)
        base = EfficientNetV2S(include_top=False, weights="imagenet")
        feats = base(x)
        ft_last = 140
    elif backbone_name == "EfficientNetV2M":
        x = layers.Lambda(effv2_preprocess, name="effv2m_preprocess")(inp)
        base = EfficientNetV2M(include_top=False, weights="imagenet")
        feats = base(x)
        ft_last = 160   # start small; increase only if stable


    else:
        raise ValueError("Unknown backbone")

    base.trainable = False
    out = build_head(feats, num_classes=NUM_CLASSES)
    model = models.Model(inp, out, name=f"Erythema_{backbone_name}")

    fine_tune_at = max(0, len(base.layers) - ft_last)
    return model, base, fine_tune_at

# %% [markdown]
# # Cell 13 — ResNet101V2 Training & Evaluation

# %%
results = []

name = "ResNet101V2"
print("\n" + "="*70)
print("🚀 Training:", name)
print("="*70)

model, base, fine_tune_at = make_model(name)

print("🧩 Stage 1: warmup (frozen backbone)")
fit_model(model, epochs=10, lr=2e-4)

print("🔧 Stage 2: fine-tune (unfreeze last layers)")
base.trainable = True
for layer in base.layers[:fine_tune_at]:
    layer.trainable = False
freeze_bn(model)
fit_model(model, epochs=15, lr=1e-5)

acc_arg, f1_arg, y_true, y_pred, _ = eval_on_test(model)
show_confusion(y_true, y_pred, f"{name} Confusion Matrix (argmax)")

best_t, best_val_f1 = best_threshold_on_val(model)
acc_thr, f1_thr, y_true_t, y_pred_t = eval_threshold(model, best_t)

results.append({
    "Model": name,
    "Argmax_ACC": acc_arg,
    "Argmax_F1W": f1_arg,
    "Best_t(VAL)": best_t,
    "Test_ACC@t": acc_thr,
    "Test_F1W@t": f1_thr
})

print(f"✅ {name} | Argmax ACC={acc_arg:.4f} F1W={f1_arg:.4f}")
print(f"✅ {name} | Best t={best_t:.2f} -> TEST ACC={acc_thr:.4f} F1W={f1_thr:.4f}")
# Out:
# ======================================================================
# 🚀 Training: ResNet101V2
# ======================================================================
# 🧩 Stage 1: warmup (frozen backbone)
# Epoch 1/10
# 695/695 [==============================] - 123s 127ms/step - loss: 0.8077 - accuracy: 0.6033 - val_loss: 0.7644 - val_accuracy: 0.6515 - lr: 2.0000e-04
# Epoch 2/10
# 695/695 [==============================] - 90s 129ms/step - loss: 0.6679 - accuracy: 0.6659 - val_loss: 0.8651 - val_accuracy: 0.5455 - lr: 2.0000e-04
# Epoch 3/10
# 695/695 [==============================] - ETA: 0s - loss: 0.5965 - accuracy: 0.6872
# Epoch 3: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-05.
# 695/695 [==============================] - 96s 137ms/step - loss: 0.5965 - accuracy: 0.6872 - val_loss: 0.8133 - val_accuracy: 0.5606 - lr: 2.0000e-04
# Epoch 4/10
# 695/695 [==============================] - 81s 117ms/step - loss: 0.5497 - accuracy: 0.7131 - val_loss: 0.7677 - val_accuracy: 0.6818 - lr: 1.0000e-04
# Epoch 5/10
# 695/695 [==============================] - ETA: 0s - loss: 0.5291 - accuracy: 0.7268
# Epoch 5: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 695/695 [==============================] - 78s 112ms/step - loss: 0.5291 - accuracy: 0.7268 - val_loss: 0.7994 - val_accuracy: 0.7273 - lr: 1.0000e-04
# Epoch 6/10
# 695/695 [==============================] - ETA: 0s - loss: 0.5085 - accuracy: 0.7505Restoring model weights from the end of the best epoch: 1.
# 695/695 [==============================] - 79s 114ms/step - loss: 0.5085 - accuracy: 0.7505 - val_loss: 0.8167 - val_accuracy: 0.6667 - lr: 5.0000e-05
# Epoch 6: early stopping
# 🔧 Stage 2: fine-tune (unfreeze last layers)
# Epoch 1/15
# 695/695 [==============================] - 102s 130ms/step - loss: 0.6780 - accuracy: 0.6422 - val_loss: 0.8541 - val_accuracy: 0.6061 - lr: 1.0000e-05
# Epoch 2/15
# 695/695 [==============================] - 81s 117ms/step - loss: 0.6269 - accuracy: 0.6652 - val_loss: 0.9081 - val_accuracy: 0.5606 - lr: 1.0000e-05
# Epoch 3/15
# 695/695 [==============================] - ETA: 0s - loss: 0.5646 - accuracy: 0.7055
# Epoch 3: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 695/695 [==============================] - 88s 126ms/step - loss: 0.5646 - accuracy: 0.7055 - val_loss: 0.9108 - val_accuracy: 0.6212 - lr: 1.0000e-05
# Epoch 4/15
# 695/695 [==============================] - 119s 171ms/step - loss: 0.5573 - accuracy: 0.7261 - val_loss: 0.9245 - val_accuracy: 0.6515 - lr: 5.0000e-06
# Epoch 5/15
# 695/695 [==============================] - ETA: 0s - loss: 0.5224 - accuracy: 0.7379
# Epoch 5: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
# 695/695 [==============================] - 102s 147ms/step - loss: 0.5224 - accuracy: 0.7379 - val_loss: 0.9158 - val_accuracy: 0.6364 - lr: 5.0000e-06
# Epoch 6/15
# 695/695 [==============================] - ETA: 0s - loss: 0.5027 - accuracy: 0.7577Restoring model weights from the end of the best epoch: 1.
# 695/695 [==============================] - 90s 130ms/step - loss: 0.5027 - accuracy: 0.7577 - val_loss: 0.9323 - val_accuracy: 0.6364 - lr: 2.5000e-06
# Epoch 6: early stopping
#               precision    recall  f1-score   support
#
#     Existent       0.51      0.55      0.53        40
# Non-existent       0.80      0.77      0.78        91
#
#     accuracy                           0.70       131
#    macro avg       0.65      0.66      0.66       131
# weighted avg       0.71      0.70      0.71       131
#
# ✅ ResNet101V2 | Argmax ACC=0.7023 F1W=0.7052
# ✅ ResNet101V2 | Best t=0.40 -> TEST ACC=0.6718 F1W=0.6829

# %%
# ✅ save the trained model (best)
model.save(f"{name}_erythema.keras")

# or weights only (lighter)
# model.save_weights(f"{name}_erythema.weights.h5")

import tensorflow as tf
tf.keras.backend.clear_session()
print(f"✅ Saved + cleared session for {name}")
# Out:
# ✅ Saved + cleared session for ResNet101V2

# %% [markdown]
# # Cell 14- EfficientNetV2M training & Evaluation

# %%
name = "EfficientNetV2M"
print("\n" + "="*70)
print("🚀 Training:", name)
print("="*70)

model, base, fine_tune_at = make_model(name)

print("🧩 Stage 1: warmup (frozen backbone)")
fit_model(model, epochs=10, lr=2e-4)

print("🔧 Stage 2: fine-tune (unfreeze last layers)")
base.trainable = True
for layer in base.layers[:fine_tune_at]:
    layer.trainable = False
freeze_bn(model)
fit_model(model, epochs=15, lr=1e-5)

acc_arg, f1_arg, y_true, y_pred, _ = eval_on_test(model)
show_confusion(y_true, y_pred, f"{name} Confusion Matrix (argmax)")

best_t, best_val_f1 = best_threshold_on_val(model)
acc_thr, f1_thr, y_true_t, y_pred_t = eval_threshold(model, best_t)

results.append({
    "Model": name,
    "Argmax_ACC": acc_arg,
    "Argmax_F1W": f1_arg,
    "Best_t(VAL)": best_t,
    "Test_ACC@t": acc_thr,
    "Test_F1W@t": f1_thr
})

print(f"✅ {name} | Argmax ACC={acc_arg:.4f} F1W={f1_arg:.4f}")
print(f"✅ {name} | Best t={best_t:.2f} -> TEST ACC={acc_thr:.4f} F1W={f1_thr:.4f}")
# Out:
# ======================================================================
# 🚀 Training: EfficientNetV2M
# ======================================================================
# 🧩 Stage 1: warmup (frozen backbone)
# Epoch 1/10
# 695/695 [==============================] - 103s 123ms/step - loss: 0.8412 - accuracy: 0.5752 - val_loss: 0.7055 - val_accuracy: 0.6061 - lr: 2.0000e-04
# Epoch 2/10
# 695/695 [==============================] - 91s 131ms/step - loss: 0.7041 - accuracy: 0.6192 - val_loss: 0.8346 - val_accuracy: 0.4394 - lr: 2.0000e-04
# Epoch 3/10
# 695/695 [==============================] - ETA: 0s - loss: 0.6353 - accuracy: 0.6602
# Epoch 3: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-05.
# 695/695 [==============================] - 91s 131ms/step - loss: 0.6353 - accuracy: 0.6602 - val_loss: 0.8070 - val_accuracy: 0.5606 - lr: 2.0000e-04
# Epoch 4/10
# 695/695 [==============================] - 87s 126ms/step - loss: 0.5704 - accuracy: 0.7030 - val_loss: 0.7926 - val_accuracy: 0.5455 - lr: 1.0000e-04
# Epoch 5/10
# 695/695 [==============================] - ETA: 0s - loss: 0.5715 - accuracy: 0.7027
# Epoch 5: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 695/695 [==============================] - 86s 124ms/step - loss: 0.5715 - accuracy: 0.7027 - val_loss: 0.7826 - val_accuracy: 0.5758 - lr: 1.0000e-04
# Epoch 6/10
# 695/695 [==============================] - ETA: 0s - loss: 0.5508 - accuracy: 0.7063Restoring model weights from the end of the best epoch: 1.
# 695/695 [==============================] - 99s 142ms/step - loss: 0.5508 - accuracy: 0.7063 - val_loss: 0.7901 - val_accuracy: 0.5909 - lr: 5.0000e-05
# Epoch 6: early stopping
# 🔧 Stage 2: fine-tune (unfreeze last layers)
# Epoch 1/15
# 695/695 [==============================] - 142s 175ms/step - loss: 0.7564 - accuracy: 0.6174 - val_loss: 0.7616 - val_accuracy: 0.5909 - lr: 1.0000e-05
# Epoch 2/15
# 695/695 [==============================] - 119s 170ms/step - loss: 0.6568 - accuracy: 0.6364 - val_loss: 0.7481 - val_accuracy: 0.5606 - lr: 1.0000e-05
# Epoch 3/15
# 695/695 [==============================] - 105s 151ms/step - loss: 0.6065 - accuracy: 0.6854 - val_loss: 0.6923 - val_accuracy: 0.5909 - lr: 1.0000e-05
# Epoch 4/15
# 695/695 [==============================] - 104s 149ms/step - loss: 0.5538 - accuracy: 0.7217 - val_loss: 0.7285 - val_accuracy: 0.5606 - lr: 1.0000e-05
# Epoch 5/15
# 695/695 [==============================] - ETA: 0s - loss: 0.4919 - accuracy: 0.7707
# Epoch 5: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 695/695 [==============================] - 106s 153ms/step - loss: 0.4919 - accuracy: 0.7707 - val_loss: 0.7695 - val_accuracy: 0.6061 - lr: 1.0000e-05
# Epoch 6/15
# 695/695 [==============================] - 118s 170ms/step - loss: 0.4646 - accuracy: 0.7783 - val_loss: 0.7901 - val_accuracy: 0.6364 - lr: 5.0000e-06
# Epoch 7/15
# 695/695 [==============================] - ETA: 0s - loss: 0.4258 - accuracy: 0.8121
# Epoch 7: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
# 695/695 [==============================] - 114s 165ms/step - loss: 0.4258 - accuracy: 0.8121 - val_loss: 0.7534 - val_accuracy: 0.6667 - lr: 5.0000e-06
# Epoch 8/15
# 695/695 [==============================] - ETA: 0s - loss: 0.4179 - accuracy: 0.8128Restoring model weights from the end of the best epoch: 3.
# 695/695 [==============================] - 122s 176ms/step - loss: 0.4179 - accuracy: 0.8128 - val_loss: 0.7278 - val_accuracy: 0.6515 - lr: 2.5000e-06
# Epoch 8: early stopping
#               precision    recall  f1-score   support
#
#     Existent       0.45      0.50      0.48        40
# Non-existent       0.77      0.74      0.75        91
#
#     accuracy                           0.66       131
#    macro avg       0.61      0.62      0.61       131
# weighted avg       0.67      0.66      0.67       131
#
# ✅ EfficientNetV2M | Argmax ACC=0.6641 F1W=0.6683
# ✅ EfficientNetV2M | Best t=0.70 -> TEST ACC=0.6794 F1W=0.6359

# %%
# ✅ save the trained model (best)
model.save(f"{name}_erythema.keras")

# or weights only (lighter)
# model.save_weights(f"{name}_erythema.weights.h5")

import tensorflow as tf
tf.keras.backend.clear_session()
print(f"✅ Saved + cleared session for {name}")
# Out:
# ✅ Saved + cleared session for EfficientNetV2M

# %% [markdown]
# # Cell 15 — ConvNeXtTiny Training & Evaluation

# %%
tf.keras.backend.clear_session()

# %%
name = "ConvNeXtTiny"
print("\n" + "="*70)
print("🚀 Training:", name)
print("="*70)

model, base, fine_tune_at = make_model(name)

print("🧩 Stage 1: warmup (frozen backbone)")
fit_model(model, epochs=10, lr=2e-4)

print("🔧 Stage 2: fine-tune (unfreeze last layers)")
base.trainable = True
for layer in base.layers[:fine_tune_at]:
    layer.trainable = False
freeze_bn(model)
fit_model(model, epochs=15, lr=8e-6)

# Argmax eval
acc_arg, f1_arg, y_true, y_pred, _ = eval_on_test(model)
show_confusion(y_true, y_pred, f"{name} Confusion Matrix (argmax)")

# Threshold eval
best_t, best_val_f1 = best_threshold_on_val(model)
acc_thr, f1_thr, y_true_t, y_pred_t = eval_threshold(model, best_t)

results.append({
    "Model": name,
    "Argmax_ACC": acc_arg,
    "Argmax_F1W": f1_arg,
    "Best_t(VAL)": best_t,
    "Test_ACC@t": acc_thr,
    "Test_F1W@t": f1_thr
})

print(f"✅ {name} | Argmax ACC={acc_arg:.4f} F1W={f1_arg:.4f}")
print(f"✅ {name} | Best t={best_t:.2f} -> TEST ACC={acc_thr:.4f} F1W={f1_thr:.4f}")
# Out:
# ======================================================================
# 🚀 Training: ConvNeXtTiny
# ======================================================================
# 🧩 Stage 1: warmup (frozen backbone)
# Epoch 1/10
# 695/695 [==============================] - 122s 154ms/step - loss: 0.8203 - accuracy: 0.5695 - val_loss: 0.7725 - val_accuracy: 0.5606 - lr: 2.0000e-04
# Epoch 2/10
# 695/695 [==============================] - 95s 136ms/step - loss: 0.6777 - accuracy: 0.6429 - val_loss: 0.7802 - val_accuracy: 0.5606 - lr: 2.0000e-04
# Epoch 3/10
# 695/695 [==============================] - ETA: 0s - loss: 0.6185 - accuracy: 0.6724
# Epoch 3: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-05.
# 695/695 [==============================] - 103s 148ms/step - loss: 0.6185 - accuracy: 0.6724 - val_loss: 0.8422 - val_accuracy: 0.5000 - lr: 2.0000e-04
# Epoch 4/10
# 695/695 [==============================] - 88s 126ms/step - loss: 0.5858 - accuracy: 0.6962 - val_loss: 0.8777 - val_accuracy: 0.5000 - lr: 1.0000e-04
# Epoch 5/10
# 695/695 [==============================] - ETA: 0s - loss: 0.5555 - accuracy: 0.7163
# Epoch 5: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 695/695 [==============================] - 90s 129ms/step - loss: 0.5555 - accuracy: 0.7163 - val_loss: 0.8313 - val_accuracy: 0.5455 - lr: 1.0000e-04
# Epoch 6/10
# 695/695 [==============================] - ETA: 0s - loss: 0.5298 - accuracy: 0.7293Restoring model weights from the end of the best epoch: 1.
# 695/695 [==============================] - 91s 130ms/step - loss: 0.5298 - accuracy: 0.7293 - val_loss: 0.8460 - val_accuracy: 0.5758 - lr: 5.0000e-05
# Epoch 6: early stopping
# 🔧 Stage 2: fine-tune (unfreeze last layers)
# Epoch 1/15
# 695/695 [==============================] - 578s 818ms/step - loss: 0.6280 - accuracy: 0.6843 - val_loss: 0.7440 - val_accuracy: 0.5909 - lr: 8.0000e-06
# Epoch 2/15
# 695/695 [==============================] - 105s 151ms/step - loss: 0.5848 - accuracy: 0.7091 - val_loss: 0.7388 - val_accuracy: 0.6212 - lr: 8.0000e-06
# Epoch 3/15
# 695/695 [==============================] - 120s 173ms/step - loss: 0.5657 - accuracy: 0.7181 - val_loss: 0.7198 - val_accuracy: 0.6364 - lr: 8.0000e-06
# Epoch 4/15
# 695/695 [==============================] - 122s 176ms/step - loss: 0.5235 - accuracy: 0.7408 - val_loss: 0.7324 - val_accuracy: 0.6515 - lr: 8.0000e-06
# Epoch 5/15
# 695/695 [==============================] - 115s 166ms/step - loss: 0.4854 - accuracy: 0.7721 - val_loss: 0.7145 - val_accuracy: 0.6515 - lr: 8.0000e-06
# Epoch 6/15
# 695/695 [==============================] - 114s 164ms/step - loss: 0.4750 - accuracy: 0.7761 - val_loss: 0.7541 - val_accuracy: 0.6364 - lr: 8.0000e-06
# Epoch 7/15
# 695/695 [==============================] - ETA: 0s - loss: 0.4225 - accuracy: 0.7988
# Epoch 7: ReduceLROnPlateau reducing learning rate to 3.999999989900971e-06.
# 695/695 [==============================] - 111s 160ms/step - loss: 0.4225 - accuracy: 0.7988 - val_loss: 0.7706 - val_accuracy: 0.6364 - lr: 8.0000e-06
# Epoch 8/15
# 695/695 [==============================] - 111s 159ms/step - loss: 0.4310 - accuracy: 0.7991 - val_loss: 0.8055 - val_accuracy: 0.5909 - lr: 4.0000e-06
# Epoch 9/15
# 695/695 [==============================] - ETA: 0s - loss: 0.4061 - accuracy: 0.8114
# Epoch 9: ReduceLROnPlateau reducing learning rate to 1.9999999949504854e-06.
# 695/695 [==============================] - 117s 168ms/step - loss: 0.4061 - accuracy: 0.8114 - val_loss: 0.8072 - val_accuracy: 0.5455 - lr: 4.0000e-06
# Epoch 10/15
# 695/695 [==============================] - ETA: 0s - loss: 0.3851 - accuracy: 0.8193Restoring model weights from the end of the best epoch: 5.
# 695/695 [==============================] - 112s 162ms/step - loss: 0.3851 - accuracy: 0.8193 - val_loss: 0.8039 - val_accuracy: 0.5909 - lr: 2.0000e-06
# Epoch 10: early stopping
#               precision    recall  f1-score   support
#
#     Existent       0.51      0.68      0.58        40
# Non-existent       0.83      0.71      0.77        91
#
#     accuracy                           0.70       131
#    macro avg       0.67      0.69      0.67       131
# weighted avg       0.73      0.70      0.71       131
#
# ✅ ConvNeXtTiny | Argmax ACC=0.7023 F1W=0.7116
# ✅ ConvNeXtTiny | Best t=0.42 -> TEST ACC=0.6489 F1W=0.6627

# %%
# ✅ save the trained model (best)
model.save(f"{name}_erythema.keras")

# or weights only (lighter)
# model.save_weights(f"{name}_erythema.weights.h5")

import tensorflow as tf
tf.keras.backend.clear_session()
print(f"✅ Saved + cleared session for {name}")
# Out:
# ✅ Saved + cleared session for ConvNeXtTiny

# %% [markdown]
# # Cell 16 — EfficientNetV2S Training & Evaluation

# %%
name = "EfficientNetV2S"
print("\n" + "="*70)
print("🚀 Training:", name)
print("="*70)

model, base, fine_tune_at = make_model(name)

print("🧩 Stage 1: warmup (frozen backbone)")
fit_model(model, epochs=10, lr=2e-4)

print("🔧 Stage 2: fine-tune (unfreeze last layers)")
base.trainable = True
for layer in base.layers[:fine_tune_at]:
    layer.trainable = False
freeze_bn(model)
fit_model(model, epochs=15, lr=6e-6)

acc_arg, f1_arg, y_true, y_pred, _ = eval_on_test(model)
show_confusion(y_true, y_pred, f"{name} Confusion Matrix (argmax)")

best_t, best_val_f1 = best_threshold_on_val(model)
acc_thr, f1_thr, y_true_t, y_pred_t = eval_threshold(model, best_t)

results.append({
    "Model": name,
    "Argmax_ACC": acc_arg,
    "Argmax_F1W": f1_arg,
    "Best_t(VAL)": best_t,
    "Test_ACC@t": acc_thr,
    "Test_F1W@t": f1_thr
})

print(f"✅ {name} | Argmax ACC={acc_arg:.4f} F1W={f1_arg:.4f}")
print(f"✅ {name} | Best t={best_t:.2f} -> TEST ACC={acc_thr:.4f} F1W={f1_thr:.4f}")
# Out:
# ======================================================================
# 🚀 Training: EfficientNetV2S
# ======================================================================
# 🧩 Stage 1: warmup (frozen backbone)
# Epoch 1/10
# 695/695 [==============================] - 88s 112ms/step - loss: 0.8437 - accuracy: 0.6112 - val_loss: 0.8761 - val_accuracy: 0.5000 - lr: 2.0000e-04
# Epoch 2/10
# 695/695 [==============================] - 109s 157ms/step - loss: 0.6788 - accuracy: 0.6465 - val_loss: 0.8087 - val_accuracy: 0.5758 - lr: 2.0000e-04
# Epoch 3/10
# 695/695 [==============================] - 74s 106ms/step - loss: 0.5880 - accuracy: 0.7016 - val_loss: 0.7926 - val_accuracy: 0.6364 - lr: 2.0000e-04
# Epoch 4/10
# 695/695 [==============================] - 75s 108ms/step - loss: 0.5935 - accuracy: 0.6973 - val_loss: 0.8433 - val_accuracy: 0.5455 - lr: 2.0000e-04
# Epoch 5/10
# 695/695 [==============================] - 92s 132ms/step - loss: 0.5428 - accuracy: 0.7228 - val_loss: 0.7548 - val_accuracy: 0.5000 - lr: 2.0000e-04
# Epoch 6/10
# 695/695 [==============================] - 89s 128ms/step - loss: 0.5532 - accuracy: 0.7131 - val_loss: 0.8813 - val_accuracy: 0.4848 - lr: 2.0000e-04
# Epoch 7/10
# 695/695 [==============================] - ETA: 0s - loss: 0.4979 - accuracy: 0.7513
# Epoch 7: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-05.
# 695/695 [==============================] - 76s 110ms/step - loss: 0.4979 - accuracy: 0.7513 - val_loss: 0.8590 - val_accuracy: 0.6364 - lr: 2.0000e-04
# Epoch 8/10
# 695/695 [==============================] - 84s 120ms/step - loss: 0.4818 - accuracy: 0.7581 - val_loss: 0.8414 - val_accuracy: 0.6212 - lr: 1.0000e-04
# Epoch 9/10
# 695/695 [==============================] - ETA: 0s - loss: 0.4899 - accuracy: 0.7711
# Epoch 9: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 695/695 [==============================] - 82s 117ms/step - loss: 0.4899 - accuracy: 0.7711 - val_loss: 0.8491 - val_accuracy: 0.6061 - lr: 1.0000e-04
# Epoch 10/10
# 695/695 [==============================] - ETA: 0s - loss: 0.4591 - accuracy: 0.7847Restoring model weights from the end of the best epoch: 5.
# 695/695 [==============================] - 76s 109ms/step - loss: 0.4591 - accuracy: 0.7847 - val_loss: 0.8810 - val_accuracy: 0.6061 - lr: 5.0000e-05
# Epoch 10: early stopping
# 🔧 Stage 2: fine-tune (unfreeze last layers)
# Epoch 1/15
# 695/695 [==============================] - 104s 127ms/step - loss: 0.6563 - accuracy: 0.6548 - val_loss: 0.6798 - val_accuracy: 0.6515 - lr: 6.0000e-06
# Epoch 2/15
# 695/695 [==============================] - 102s 146ms/step - loss: 0.6040 - accuracy: 0.6825 - val_loss: 0.6870 - val_accuracy: 0.6515 - lr: 6.0000e-06
# Epoch 3/15
# 695/695 [==============================] - ETA: 0s - loss: 0.5490 - accuracy: 0.7084
# Epoch 3: ReduceLROnPlateau reducing learning rate to 3.000000106112566e-06.
# 695/695 [==============================] - 101s 145ms/step - loss: 0.5490 - accuracy: 0.7084 - val_loss: 0.7012 - val_accuracy: 0.6970 - lr: 6.0000e-06
# Epoch 4/15
# 695/695 [==============================] - 107s 154ms/step - loss: 0.5465 - accuracy: 0.7250 - val_loss: 0.7052 - val_accuracy: 0.6818 - lr: 3.0000e-06
# Epoch 5/15
# 695/695 [==============================] - ETA: 0s - loss: 0.5196 - accuracy: 0.7469
# Epoch 5: ReduceLROnPlateau reducing learning rate to 1.500000053056283e-06.
# 695/695 [==============================] - 113s 163ms/step - loss: 0.5196 - accuracy: 0.7469 - val_loss: 0.6864 - val_accuracy: 0.6970 - lr: 3.0000e-06
# Epoch 6/15
# 695/695 [==============================] - ETA: 0s - loss: 0.5241 - accuracy: 0.7415Restoring model weights from the end of the best epoch: 1.
# 695/695 [==============================] - 118s 169ms/step - loss: 0.5241 - accuracy: 0.7415 - val_loss: 0.6836 - val_accuracy: 0.6970 - lr: 1.5000e-06
# Epoch 6: early stopping
#               precision    recall  f1-score   support
#
#     Existent       0.43      0.68      0.52        40
# Non-existent       0.81      0.60      0.69        91
#
#     accuracy                           0.63       131
#    macro avg       0.62      0.64      0.61       131
# weighted avg       0.69      0.63      0.64       131
#
# ✅ EfficientNetV2S | Argmax ACC=0.6260 F1W=0.6407
# ✅ EfficientNetV2S | Best t=0.49 -> TEST ACC=0.6183 F1W=0.6334

# %%
# ✅ save the trained model (best)
model.save(f"{name}_erythema.keras")

# or weights only (lighter)
# model.save_weights(f"{name}_erythema.weights.h5")

import tensorflow as tf
tf.keras.backend.clear_session()
print(f"✅ Saved + cleared session for {name}")
# Out:
# ✅ Saved + cleared session for EfficientNetV2S

# %% [markdown]
# # Cell 17 — Model Comparison & Final Selection

# %%
results_df = pd.DataFrame(results).sort_values("Test_F1W@t", ascending=False).reset_index(drop=True)
display(results_df)

best = results_df.iloc[0]
print(f"\n🏆 BEST MODEL = {best['Model']} | Test_ACC@t={best['Test_ACC@t']:.4f} | Test_F1W@t={best['Test_F1W@t']:.4f} | Best_t={best['Best_t(VAL)']:.2f}")

results_df.to_csv("erythema_augtrain_cleanval_best3_results.csv", index=False)
print("✅ Saved: erythema_augtrain_cleanval_best3_results.csv")
# Out:
#              Model  Argmax_ACC  Argmax_F1W  Best_t(VAL)  Test_ACC@t  \
# 0      ResNet101V2    0.702290    0.705176         0.40    0.671756
# 1     ConvNeXtTiny    0.702290    0.711647         0.42    0.648855
# 2  EfficientNetV2M    0.664122    0.668345         0.70    0.679389
# 3  EfficientNetV2S    0.625954    0.640663         0.49    0.618321
#
#    Test_F1W@t
# 0    0.682928
# 1    0.662658
# 2    0.635872
# 3    0.633372
# 🏆 BEST MODEL = ResNet101V2 | Test_ACC@t=0.6718 | Test_F1W@t=0.6829 | Best_t=0.40
# ✅ Saved: erythema_augtrain_cleanval_best3_results.csv
