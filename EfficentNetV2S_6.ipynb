# %%
import os, numpy as np, pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.utils import class_weight
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, classification_report

import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %% [markdown]
# # Cell 2 — TensorFlow Configuration (GPU, Precision, XLA)

# %%
print("TF version:", tf.__version__)
print("GPUs:", tf.config.list_physical_devices("GPU"))
print("Logical devices:", tf.config.list_logical_devices())

tf.config.optimizer.set_jit(False)   # keep OFF


# Seed
SEED = 42
tf.keras.utils.set_random_seed(SEED)
# Out:
# TF version: 2.10.1
# GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Logical devices: [LogicalDevice(name='/device:CPU:0', device_type='CPU'), LogicalDevice(name='/device:GPU:0', device_type='GPU')]

# %%
print("TF version:", tf.__version__)
print("GPUs:", tf.config.list_physical_devices("GPU"))
# Out:
# TF version: 2.10.1
# GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
from tensorflow.keras import mixed_precision
mixed_precision.set_global_policy("float32")
print("Policy:", mixed_precision.global_policy())
# Out:
# Policy: <Policy "float32">

# %% [markdown]
# # Cell 3 -Load CSV Flies

# %%
import os

BASE_DIR = r"C:\Users\norah\Downloads\aidx-medical-app-master\aidx-medical-app-master\Ratq_Model"

print("📂 BASE_DIR:", BASE_DIR)

TRAIN_DIR = os.path.join(BASE_DIR, "SurgWound_Augmented")
CLEAN_DIR = os.path.join(BASE_DIR, "SurgWound_Cleaned")

TRAIN_CSV = os.path.join(TRAIN_DIR, "train_aug_data.csv")
VAL_CSV   = os.path.join(CLEAN_DIR, "validation_data.csv")
TEST_CSV  = os.path.join(CLEAN_DIR, "test_data.csv")

print("TRAIN_CSV:", TRAIN_CSV)
print("VAL_CSV:", VAL_CSV)
print("TEST_CSV:", TEST_CSV)

assert os.path.isfile(TRAIN_CSV), f"❌ Missing: {TRAIN_CSV}"
assert os.path.isfile(VAL_CSV),   f"❌ Missing: {VAL_CSV}"
assert os.path.isfile(TEST_CSV),  f"❌ Missing: {TEST_CSV}"

print("✅ CSVs found — paths are correct")
# Out:
# 📂 BASE_DIR: C:\Users\norah\Downloads\aidx-medical-app-master\aidx-medical-app-master\Ratq_Model
# TRAIN_CSV: C:\Users\norah\Downloads\aidx-medical-app-master\aidx-medical-app-master\Ratq_Model\SurgWound_Augmented\train_aug_data.csv
# VAL_CSV: C:\Users\norah\Downloads\aidx-medical-app-master\aidx-medical-app-master\Ratq_Model\SurgWound_Cleaned\validation_data.csv
# TEST_CSV: C:\Users\norah\Downloads\aidx-medical-app-master\aidx-medical-app-master\Ratq_Model\SurgWound_Cleaned\test_data.csv
# ✅ CSVs found — paths are correct

# %% [markdown]
# #  Cell 4 — Load & Filter Erythema Samples

# %%
def load_task(df, task_key="erythema"):
    df = df.copy()
    df = df[df["image_id"].astype(str).str.contains(task_key, case=False, na=False)]
    df = df[df["answer"].astype(str).str.lower() != "uncertain"]
    df["answer"] = df["answer"].astype(str).str.strip()
    df["filename"] = (
        df["filename"].astype(str)
        .str.replace("\\\\", "/", regex=False)
        .str.replace("\\", "/", regex=False)
    )
    return df.reset_index(drop=True)

train_df = load_task(pd.read_csv(TRAIN_CSV), "erythema")
val_df   = load_task(pd.read_csv(VAL_CSV),   "erythema")
test_df  = load_task(pd.read_csv(TEST_CSV),  "erythema")

print("Train:\n", train_df["answer"].value_counts())
print("Val:\n", val_df["answer"].value_counts())
print("Test:\n", test_df["answer"].value_counts())
# Out:
# Train:
#  answer
# Non-existent    2004
# Existent         774
# Name: count, dtype: int64
# Val:
#  answer
# Non-existent    44
# Existent        22
# Name: count, dtype: int64
# Test:
#  answer
# Non-existent    91
# Existent        40
# Name: count, dtype: int64

# %% [markdown]
# # Cell 5 — Dataset Sanity Check

# %%
p = os.path.join(TRAIN_DIR, train_df["filename"].iloc[0])
print("Example train file:", train_df["filename"].iloc[0])
print("Exists?", os.path.exists(p))
assert os.path.exists(p), "❌ Train augmented image path mismatch."
print("✅ Paths OK")
# Out:
# Example train file: train/images/0.jpg_erythema.jpg
# Exists? True
# ✅ Paths OK

# %% [markdown]
# # Cell 6 — Image Size & Data Generators

# %%
IMG_SIZE = (224, 224)
BATCH_SIZE = 8   # if still OOM -> 4

# %% [markdown]
# # Cell 7 — Class Imbalance Handling

# %%
train_datagen = ImageDataGenerator(
    brightness_range=[0.8, 1.2],
    channel_shift_range=20.0,
    rotation_range=30,
    width_shift_range=0.10,
    height_shift_range=0.10,
    zoom_range=0.20,
    horizontal_flip=True,
    fill_mode="nearest"
)

val_datagen = ImageDataGenerator()  # clean, no augmentation

train_gen = train_datagen.flow_from_dataframe(
    dataframe=train_df,
    directory=TRAIN_DIR,
    x_col="filename",
    y_col="answer",
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="sparse",
    shuffle=True,
    seed=SEED
)

val_gen = val_datagen.flow_from_dataframe(
    dataframe=val_df,
    directory=CLEAN_DIR,
    x_col="filename",
    y_col="answer",
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="sparse",
    shuffle=False
)

test_gen = val_datagen.flow_from_dataframe(
    dataframe=test_df,
    directory=CLEAN_DIR,
    x_col="filename",
    y_col="answer",
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="sparse",
    shuffle=False
)

print("✅ class_indices:", train_gen.class_indices)
NUM_CLASSES = len(train_gen.class_indices)
assert NUM_CLASSES == 2, "Expected 2 classes for erythema."
# Out:
# Found 2778 validated image filenames belonging to 2 classes.
# Found 66 validated image filenames belonging to 2 classes.
# Found 131 validated image filenames belonging to 2 classes.
# ✅ class_indices: {'Existent': 0, 'Non-existent': 1}

# %% [markdown]
# # Cell 8 — Training Utilities (Compile & Fit)

# %%
y_train = np.array(train_gen.classes, dtype=int)
classes = np.arange(NUM_CLASSES, dtype=int)

weights = class_weight.compute_class_weight(
    class_weight="balanced",
    classes=classes,
    y=y_train
)
CLASS_WEIGHTS = {int(c): float(w) for c, w in zip(classes, weights)}
print("Class weights:", CLASS_WEIGHTS)
# Out:
# Class weights: {0: 1.7945736434108528, 1: 0.6931137724550899}

# %% [markdown]
# # Cell 9,10 — Evaluation & Threshold Optimization

# %%
def freeze_bn(model):
    for l in model.layers:
        if isinstance(l, layers.BatchNormalization):
            l.trainable = False

def compile_model(model, lr, label_smoothing=0.0):
    opt = tf.keras.optimizers.Adam(learning_rate=lr)

    if label_smoothing and label_smoothing > 0:
        loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(label_smoothing=label_smoothing)
    else:
        loss_fn = "sparse_categorical_crossentropy"

    model.compile(optimizer=opt, loss=loss_fn, metrics=["accuracy"])
    return model

def fit_model(model, epochs, lr):
    compile_model(model, lr=lr)
    cbs = [
        ReduceLROnPlateau(monitor="val_loss", patience=2, factor=0.5, min_lr=1e-7, verbose=1),
        EarlyStopping(monitor="val_loss", patience=5, restore_best_weights=True, verbose=1),
    ]
    return model.fit(
        train_gen,
        validation_data=val_gen,
        epochs=epochs,
        class_weight=CLASS_WEIGHTS,
        callbacks=cbs,
        verbose=1,
        workers=1,
        use_multiprocessing=False
    )

# %%
def predict_probs(model, loader):
    probs = model.predict(loader, verbose=0)
    probs = np.array(probs)
    if probs.ndim == 1:
        probs = np.stack([1 - probs, probs], axis=1)
    return probs

def eval_on_test(model):
    probs = predict_probs(model, test_gen)
    y_pred = np.argmax(probs, axis=1)
    y_true = np.array(test_gen.classes, dtype=int)
    acc = accuracy_score(y_true, y_pred)
    f1w = f1_score(y_true, y_pred, average="weighted", zero_division=0)
    return acc, f1w, y_true, y_pred, probs

def best_threshold_on_val(model):
    probs = predict_probs(model, val_gen)
    y_val = np.array(val_gen.classes, dtype=int)

    # pick positive class index safely
    if "Existent" in train_gen.class_indices:
        ex_idx = train_gen.class_indices["Existent"]
    else:
        ex_idx = 1  # fallback: assume class 1 is positive

    p_ex = probs[:, ex_idx]
    best_t, best_f1 = 0.5, -1
    for t in np.arange(0.05, 0.96, 0.01):
        y_pred_t = np.where(p_ex >= t, ex_idx, 1 - ex_idx)
        f1w_t = f1_score(y_val, y_pred_t, average="weighted", zero_division=0)
        if f1w_t > best_f1:
            best_f1, best_t = f1w_t, t
    return float(best_t), float(best_f1)

def eval_threshold(model, t):
    probs = predict_probs(model, test_gen)
    y_true = np.array(test_gen.classes, dtype=int)

    if "Existent" in train_gen.class_indices:
        ex_idx = train_gen.class_indices["Existent"]
    else:
        ex_idx = 1

    p_ex = probs[:, ex_idx]
    y_pred = np.where(p_ex >= t, ex_idx, 1 - ex_idx)
    acc = accuracy_score(y_true, y_pred)
    f1w = f1_score(y_true, y_pred, average="weighted", zero_division=0)
    return float(acc), float(f1w), y_true, y_pred

# %% [markdown]
# # Cell 11 — Confusion Matrix Visualization

# %%
def show_confusion(y_true, y_pred, title):
    labels = {v: k for k, v in train_gen.class_indices.items()}
    class_names = [labels[i] for i in range(len(labels))]

    cm = confusion_matrix(y_true, y_pred)

    plt.figure(figsize=(5.5, 5))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
                xticklabels=class_names, yticklabels=class_names)
    plt.title(title)
    plt.xlabel("Predicted")
    plt.ylabel("True")
    plt.tight_layout()
    plt.show()

    print(classification_report(y_true, y_pred, target_names=class_names))

# %% [markdown]
# # Cell 12 — Model Architectures & Head Definition

# %%
from tensorflow.keras.applications import EfficientNetV2S, ConvNeXtTiny, ResNet101V2
from tensorflow.keras.applications.efficientnet_v2 import preprocess_input as effv2_preprocess
from tensorflow.keras.applications.convnext import preprocess_input as convnext_preprocess
from tensorflow.keras.applications.resnet_v2 import preprocess_input as resnetv2_preprocess
from tensorflow.keras.applications import EfficientNetV2M
from tensorflow.keras.applications.efficientnet_v2 import preprocess_input as effv2_preprocess
from tensorflow.keras.applications import EfficientNetV2B0, EfficientNetV2B1, EfficientNetV2B2, EfficientNetV2B3
from tensorflow.keras.applications import EfficientNetB0, EfficientNetB3, EfficientNetB4
from tensorflow.keras.applications.efficientnet_v2 import preprocess_input as effv2_preprocess
from tensorflow.keras.applications.efficientnet import preprocess_input as eff_preprocess

def build_head(x, num_classes=2):
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dense(512, activation="relu")(x)
    x = layers.Dropout(0.45)(x)
    x = layers.Dense(128, activation="relu")(x)
    x = layers.Dropout(0.25)(x)
    # ✅ important for mixed precision stability
    return layers.Dense(num_classes, activation="softmax", dtype="float32")(x)

def make_model(backbone_name):
    inp = tf.keras.Input(shape=(IMG_SIZE[0], IMG_SIZE[1], 3))

    if backbone_name == "EfficientNetV2S":
        x = layers.Lambda(effv2_preprocess, name="effv2_preprocess")(inp)
        base = EfficientNetV2S(include_top=False, weights="imagenet")
        feats = base(x)
        ft_last = 140
    elif backbone_name == "EfficientNetV2M":
        x = layers.Lambda(effv2_preprocess, name="effv2m_preprocess")(inp)
        base = EfficientNetV2M(include_top=False, weights="imagenet")
        feats = base(x)
        ft_last = 160   # start small; increase only if stable
        # -------- EfficientNetV2 B family (good & lighter) --------
    elif backbone_name == "EfficientNetV2B0":
        x = layers.Lambda(effv2_preprocess, name="effv2b0_preprocess")(inp)
        base = EfficientNetV2B0(include_top=False, weights="imagenet")
        feats = base(x)
        ft_last = 120

    elif backbone_name == "EfficientNetV2B1":
        x = layers.Lambda(effv2_preprocess, name="effv2b1_preprocess")(inp)
        base = EfficientNetV2B1(include_top=False, weights="imagenet")
        feats = base(x)
        ft_last = 130

    elif backbone_name == "EfficientNetV2B2":
        x = layers.Lambda(effv2_preprocess, name="effv2b2_preprocess")(inp)
        base = EfficientNetV2B2(include_top=False, weights="imagenet")
        feats = base(x)
        ft_last = 140

    elif backbone_name == "EfficientNetV2B3":
        x = layers.Lambda(effv2_preprocess, name="effv2b3_preprocess")(inp)
        base = EfficientNetV2B3(include_top=False, weights="imagenet")
        feats = base(x)
        ft_last = 150


    # -------- Old EfficientNet (sometimes great on medical) --------
    elif backbone_name == "EfficientNetB0":
        x = layers.Lambda(eff_preprocess, name="effb0_preprocess")(inp)
        base = EfficientNetB0(include_top=False, weights="imagenet")
        feats = base(x)
        ft_last = 110

    elif backbone_name == "EfficientNetB3":
        x = layers.Lambda(eff_preprocess, name="effb3_preprocess")(inp)
        base = EfficientNetB3(include_top=False, weights="imagenet")
        feats = base(x)
        ft_last = 130

    elif backbone_name == "EfficientNetB4":
        x = layers.Lambda(eff_preprocess, name="effb4_preprocess")(inp)
        base = EfficientNetB4(include_top=False, weights="imagenet")
        feats = base(x)
        ft_last = 140


    else:
        raise ValueError("Unknown backbone")

    base.trainable = False
    out = build_head(feats, num_classes=NUM_CLASSES)
    model = models.Model(inp, out, name=f"Erythema_{backbone_name}")

    fine_tune_at = max(0, len(base.layers) - ft_last)
    return model, base, fine_tune_at

# %% [markdown]
# # Cell 16 — EfficientNetV2S Training & Evaluation

# %%
results = []
name = "EfficientNetV2S"
print("\n" + "="*70)
print("🚀 Training:", name)
print("="*70)

model, base, fine_tune_at = make_model(name)

print("🧩 Stage 1: warmup (frozen backbone)")
fit_model(model, epochs=20, lr=2e-4)

print("🔧 Stage 2: fine-tune (unfreeze last layers)")
base.trainable = True
for layer in base.layers[:fine_tune_at]:
    layer.trainable = False
freeze_bn(model)
fit_model(model, epochs=36, lr=6e-6)

acc_arg, f1_arg, y_true, y_pred, _ = eval_on_test(model)
show_confusion(y_true, y_pred, f"{name} Confusion Matrix (argmax)")

best_t, best_val_f1 = best_threshold_on_val(model)
acc_thr, f1_thr, y_true_t, y_pred_t = eval_threshold(model, best_t)

results.append({
    "Model": name,
    "Argmax_ACC": acc_arg,
    "Argmax_F1W": f1_arg,
    "Best_t(VAL)": best_t,
    "Test_ACC@t": acc_thr,
    "Test_F1W@t": f1_thr
})

print(f"✅ {name} | Argmax ACC={acc_arg:.4f} F1W={f1_arg:.4f}")
print(f"✅ {name} | Best t={best_t:.2f} -> TEST ACC={acc_thr:.4f} F1W={f1_thr:.4f}")
# Out:
# ======================================================================
# 🚀 Training: EfficientNetV2S
# ======================================================================
# 🧩 Stage 1: warmup (frozen backbone)
# Epoch 1/20
# 348/348 [==============================] - 99s 218ms/step - loss: 0.8482 - accuracy: 0.5788 - val_loss: 0.7673 - val_accuracy: 0.5909 - lr: 2.0000e-04
# Epoch 2/20
# 348/348 [==============================] - 62s 178ms/step - loss: 0.6580 - accuracy: 0.6832 - val_loss: 0.8592 - val_accuracy: 0.5152 - lr: 2.0000e-04
# Epoch 3/20
# 348/348 [==============================] - ETA: 0s - loss: 0.5856 - accuracy: 0.7055
# Epoch 3: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-05.
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 1.500000053056283e-06.
# 348/348 [==============================] - 71s 203ms/step - loss: 0.4884 - accuracy: 0.7761 - val_loss: 0.6982 - val_accuracy: 0.7121 - lr: 3.0000e-06
# Epoch 11/36
# 348/348 [==============================] - ETA: 0s - loss: 0.5159 - accuracy: 0.7534Restoring model weights from the end of the best epoch: 6.
# 348/348 [==============================] - 69s 199ms/step - loss: 0.5159 - accuracy: 0.7534 - val_loss: 0.7221 - val_accuracy: 0.6212 - lr: 1.5000e-06
# Epoch 11: early stopping
#               precision    recall  f1-score   support
#
#     Existent       0.60      0.68      0.64        40
# Non-existent       0.85      0.80      0.82        91
#
#     accuracy                           0.76       131
#    macro avg       0.72      0.74      0.73       131
# weighted avg       0.77      0.76      0.77       131
#
# ✅ EfficientNetV2S | Argmax ACC=0.7634 F1W=0.7670
# ✅ EfficientNetV2S | Best t=0.62 -> TEST ACC=0.7481 F1W=0.7381

# %%
# ✅ save the trained model (best)
model.save(f"{name}_erythema.keras")

# or weights only (lighter)
# model.save_weights(f"{name}_erythema.weights.h5")

import tensorflow as tf
tf.keras.backend.clear_session()
print(f"✅ Saved + cleared session for {name}")
# Out:
# ✅ Saved + cleared session for EfficientNetV2S

# %% [markdown]
# # EfficientNetV2B3

# %%
name = "EfficientNetV2B3"
print("\n" + "="*70)
print("🚀 Training:", name)
print("="*70)

model, base, fine_tune_at = make_model(name)

print("🧩 Stage 1: warmup (frozen backbone)")
fit_model(model, epochs=20, lr=2e-4)

print("🔧 Stage 2: fine-tune (unfreeze last layers)")
base.trainable = True
for layer in base.layers[:fine_tune_at]:
    layer.trainable = False
freeze_bn(model)
fit_model(model, epochs=36, lr=6e-6)

acc_arg, f1_arg, y_true, y_pred, _ = eval_on_test(model)
show_confusion(y_true, y_pred, f"{name} Confusion Matrix (argmax)")

best_t, best_val_f1 = best_threshold_on_val(model)
acc_thr, f1_thr, y_true_t, y_pred_t = eval_threshold(model, best_t)

results.append({
    "Model": name,
    "Argmax_ACC": acc_arg,
    "Argmax_F1W": f1_arg,
    "Best_t(VAL)": best_t,
    "Test_ACC@t": acc_thr,
    "Test_F1W@t": f1_thr
})

print(f"✅ {name} | Argmax ACC={acc_arg:.4f} F1W={f1_arg:.4f}")
print(f"✅ {name} | Best t={best_t:.2f} -> TEST ACC={acc_thr:.4f} F1W={f1_thr:.4f}")
# Out:
# ======================================================================
# 🚀 Training: EfficientNetV2B3
# ======================================================================
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-b3_notop.h5
# 52606240/52606240 [==============================] - 16s 0us/step
# 🧩 Stage 1: warmup (frozen backbone)
# Epoch 1/20
# 348/348 [==============================] - 91s 240ms/step - loss: 0.8827 - accuracy: 0.5803 - val_loss: 0.8943 - val_accuracy: 0.5000 - lr: 2.0000e-04
# Epoch 2/20
# 348/348 [==============================] - 65s 185ms/step - loss: 0.6836 - accuracy: 0.6551 - val_loss: 0.7649 - val_accuracy: 0.5909 - lr: 2.0000e-04
# Epoch 3/20
# 348/348 [==============================] - 63s 180ms/step - loss: 0.5639 - accuracy: 0.7149 - val_loss: 0.8086 - val_accuracy: 0.5303 - lr: 2.0000e-04
# Epoch 4/20
# 348/348 [==============================] - ETA: 0s - loss: 0.5678 - accuracy: 0.7124
# Epoch 4: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-05.
#
36
# 348/348 [==============================] - ETA: 0s - loss: 0.5673 - accuracy: 0.7160
# Epoch 11: ReduceLROnPlateau reducing learning rate to 7.500000265281415e-07.
# 348/348 [==============================] - 68s 194ms/step - loss: 0.5673 - accuracy: 0.7160 - val_loss: 0.7309 - val_accuracy: 0.6061 - lr: 1.5000e-06
# Epoch 12/36
# 348/348 [==============================] - ETA: 0s - loss: 0.5653 - accuracy: 0.7142Restoring model weights from the end of the best epoch: 7.
# 348/348 [==============================] - 68s 194ms/step - loss: 0.5653 - accuracy: 0.7142 - val_loss: 0.6991 - val_accuracy: 0.6061 - lr: 7.5000e-07
# Epoch 12: early stopping
#               precision    recall  f1-score   support
#
#     Existent       0.49      0.57      0.53        40
# Non-existent       0.80      0.74      0.77        91
#
#     accuracy                           0.69       131
#    macro avg       0.64      0.66      0.65       131
# weighted avg       0.70      0.69      0.69       131
#
# ✅ EfficientNetV2B3 | Argmax ACC=0.6870 F1W=0.6934
# ✅ EfficientNetV2B3 | Best t=0.54 -> TEST ACC=0.7023 F1W=0.6989

# %%
# ✅ save the trained model (best)
model.save(f"{name}_erythema.keras")

# or weights only (lighter)
# model.save_weights(f"{name}_erythema.weights.h5")

import tensorflow as tf
tf.keras.backend.clear_session()
print(f"✅ Saved + cleared session for {name}")
# Out:
# ✅ Saved + cleared session for EfficientNetV2B3

# %% [markdown]
# # EfficientNetV2B2

# %%
name = "EfficientNetV2B2"
print("\n" + "="*70)
print("🚀 Training:", name)
print("="*70)

model, base, fine_tune_at = make_model(name)

print("🧩 Stage 1: warmup (frozen backbone)")
fit_model(model, epochs=20, lr=2e-4)

print("🔧 Stage 2: fine-tune (unfreeze last layers)")
base.trainable = True
for layer in base.layers[:fine_tune_at]:
    layer.trainable = False
freeze_bn(model)
fit_model(model, epochs=36, lr=6e-6)

acc_arg, f1_arg, y_true, y_pred, _ = eval_on_test(model)
show_confusion(y_true, y_pred, f"{name} Confusion Matrix (argmax)")

best_t, best_val_f1 = best_threshold_on_val(model)
acc_thr, f1_thr, y_true_t, y_pred_t = eval_threshold(model, best_t)

results.append({
    "Model": name,
    "Argmax_ACC": acc_arg,
    "Argmax_F1W": f1_arg,
    "Best_t(VAL)": best_t,
    "Test_ACC@t": acc_thr,
    "Test_F1W@t": f1_thr
})

print(f"✅ {name} | Argmax ACC={acc_arg:.4f} F1W={f1_arg:.4f}")
print(f"✅ {name} | Best t={best_t:.2f} -> TEST ACC={acc_thr:.4f} F1W={f1_thr:.4f}")
# Out:
# ======================================================================
# 🚀 Training: EfficientNetV2B2
# ======================================================================
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-b2_notop.h5
# 35839040/35839040 [==============================] - 8s 0us/step
# 🧩 Stage 1: warmup (frozen backbone)
# Epoch 1/20
# 348/348 [==============================] - 70s 173ms/step - loss: 0.8242 - accuracy: 0.6026 - val_loss: 0.7564 - val_accuracy: 0.6061 - lr: 2.0000e-04
# Epoch 2/20
# 348/348 [==============================] - 57s 164ms/step - loss: 0.6532 - accuracy: 0.6724 - val_loss: 0.7970 - val_accuracy: 0.5758 - lr: 2.0000e-04
# Epoch 3/20
# Epoch 8: ReduceLROnPlateau reducing learning rate to 1.500000053056283e-06.
# 348/348 [==============================] - 64s 184ms/step - loss: 0.5385 - accuracy: 0.7171 - val_loss: 0.6968 - val_accuracy: 0.6818 - lr: 3.0000e-06
# Epoch 9/36
# 348/348 [==============================] - 65s 187ms/step - loss: 0.5361 - accuracy: 0.7394 - val_loss: 0.6874 - val_accuracy: 0.6818 - lr: 1.5000e-06
# Epoch 10/36
# 348/348 [==============================] - 64s 185ms/step - loss: 0.5420 - accuracy: 0.7181 - val_loss: 0.7105 - val_accuracy: 0.6212 - lr: 1.5000e-06
# Epoch 11/36
# 348/348 [==============================] - ETA: 0s - loss: 0.5319 - accuracy: 0.7286
# Epoch 11: ReduceLROnPlateau reducing learning rate to 7.500000265281415e-07.
# 348/348 [==============================] - 65s 187ms/step - loss: 0.5319 - accuracy: 0.7286 - val_loss: 0.6928 - val_accuracy: 0.6667 - lr: 1.5000e-06
# Epoch 12/36
# 348/348 [==============================] - 66s 188ms/step - loss: 0.5220 - accuracy: 0.7405 - val_loss: 0.6978 - val_accuracy: 0.6667 - lr: 7.5000e-07
# Epoch 13/36
# 348/348 [==============================] - ETA: 0s - loss: 0.5315 - accuracy: 0.7275
# Epoch 13: ReduceLROnPlateau reducing learning rate to 3.7500001326407073e-07.
# 348/348 [==============================] - 71s 204ms/step - loss: 0.5315 - accuracy: 0.7275 - val_loss: 0.6962 - val_accuracy: 0.6667 - lr: 7.5000e-07
# Epoch 14/36
# 348/348 [==============================] - ETA: 0s - loss: 0.5452 - accuracy: 0.7293Restoring model weights from the end of the best epoch: 9.
# 348/348 [==============================] - 70s 201ms/step - loss: 0.5452 - accuracy: 0.7293 - val_loss: 0.7067 - val_accuracy: 0.6515 - lr: 3.7500e-07
# Epoch 14: early stopping
#               precision    recall  f1-score   support
#
#     Existent       0.51      0.68      0.58        40
# Non-existent       0.83      0.71      0.77        91
#
#     accuracy                           0.70       131
#    macro avg       0.67      0.69      0.67       131
# weighted avg       0.73      0.70      0.71       131
#
# ✅ EfficientNetV2B2 | Argmax ACC=0.7023 F1W=0.7116
# ✅ EfficientNetV2B2 | Best t=0.54 -> TEST ACC=0.6870 F1W=0.6918

# %%
# ✅ save the trained model (best)
model.save(f"{name}_erythema.keras")

# or weights only (lighter)
# model.save_weights(f"{name}_erythema.weights.h5")

import tensorflow as tf
tf.keras.backend.clear_session()
print(f"✅ Saved + cleared session for {name}")
# Out:
# ✅ Saved + cleared session for EfficientNetV2B2

# %% [markdown]
# # EfficientNetV2B1

# %%
name = "EfficientNetV2B1"
print("\n" + "="*70)
print("🚀 Training:", name)
print("="*70)

model, base, fine_tune_at = make_model(name)

print("🧩 Stage 1: warmup (frozen backbone)")
fit_model(model, epochs=20, lr=2e-4)

print("🔧 Stage 2: fine-tune (unfreeze last layers)")
base.trainable = True
for layer in base.layers[:fine_tune_at]:
    layer.trainable = False
freeze_bn(model)
fit_model(model, epochs=36, lr=6e-6)

acc_arg, f1_arg, y_true, y_pred, _ = eval_on_test(model)
show_confusion(y_true, y_pred, f"{name} Confusion Matrix (argmax)")

best_t, best_val_f1 = best_threshold_on_val(model)
acc_thr, f1_thr, y_true_t, y_pred_t = eval_threshold(model, best_t)

results.append({
    "Model": name,
    "Argmax_ACC": acc_arg,
    "Argmax_F1W": f1_arg,
    "Best_t(VAL)": best_t,
    "Test_ACC@t": acc_thr,
    "Test_F1W@t": f1_thr
})

print(f"✅ {name} | Argmax ACC={acc_arg:.4f} F1W={f1_arg:.4f}")
print(f"✅ {name} | Best t={best_t:.2f} -> TEST ACC={acc_thr:.4f} F1W={f1_thr:.4f}")
# Out:
# ======================================================================
# 🚀 Training: EfficientNetV2B1
# ======================================================================
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-
ReduceLROnPlateau reducing learning rate to 3.000000106112566e-06.
# 348/348 [==============================] - 65s 186ms/step - loss: 0.5982 - accuracy: 0.6926 - val_loss: 0.7251 - val_accuracy: 0.5152 - lr: 6.0000e-06
# Epoch 8/36
# 348/348 [==============================] - 63s 181ms/step - loss: 0.5800 - accuracy: 0.6983 - val_loss: 0.7152 - val_accuracy: 0.5303 - lr: 3.0000e-06
# Epoch 9/36
# 348/348 [==============================] - ETA: 0s - loss: 0.5827 - accuracy: 0.6915
# Epoch 9: ReduceLROnPlateau reducing learning rate to 1.500000053056283e-06.
# 348/348 [==============================] - 64s 184ms/step - loss: 0.5827 - accuracy: 0.6915 - val_loss: 0.7406 - val_accuracy: 0.4848 - lr: 3.0000e-06
# Epoch 10/36
# 348/348 [==============================] - ETA: 0s - loss: 0.5730 - accuracy: 0.7059Restoring model weights from the end of the best epoch: 5.
# 348/348 [==============================] - 69s 197ms/step - loss: 0.5730 - accuracy: 0.7059 - val_loss: 0.7198 - val_accuracy: 0.5606 - lr: 1.5000e-06
# Epoch 10: early stopping
#               precision    recall  f1-score   support
#
#     Existent       0.41      0.57      0.48        40
# Non-existent       0.77      0.64      0.70        91
#
#     accuracy                           0.62       131
#    macro avg       0.59      0.61      0.59       131
# weighted avg       0.66      0.62      0.63       131
#
# ✅ EfficientNetV2B1 | Argmax ACC=0.6183 F1W=0.6317
# ✅ EfficientNetV2B1 | Best t=0.59 -> TEST ACC=0.7252 F1W=0.7127

# %%
# ✅ save the trained model (best)
model.save(f"{name}_erythema.keras")

# or weights only (lighter)
# model.save_weights(f"{name}_erythema.weights.h5")

import tensorflow as tf
tf.keras.backend.clear_session()
print(f"✅ Saved + cleared session for {name}")
# Out:
# ✅ Saved + cleared session for EfficientNetV2B1

# %% [markdown]
# # EfficientNetB3

# %%
name = "EfficientNetV2B3"
print("\n" + "="*70)
print("🚀 Training:", name)
print("="*70)

model, base, fine_tune_at = make_model(name)

print("🧩 Stage 1: warmup (frozen backbone)")
fit_model(model, epochs=20, lr=2e-4)

print("🔧 Stage 2: fine-tune (unfreeze last layers)")
base.trainable = True
for layer in base.layers[:fine_tune_at]:
    layer.trainable = False
freeze_bn(model)
fit_model(model, epochs=36, lr=6e-6)

acc_arg, f1_arg, y_true, y_pred, _ = eval_on_test(model)
show_confusion(y_true, y_pred, f"{name} Confusion Matrix (argmax)")

best_t, best_val_f1 = best_threshold_on_val(model)
acc_thr, f1_thr, y_true_t, y_pred_t = eval_threshold(model, best_t)

results.append({
    "Model": name,
    "Argmax_ACC": acc_arg,
    "Argmax_F1W": f1_arg,
    "Best_t(VAL)": best_t,
    "Test_ACC@t": acc_thr,
    "Test_F1W@t": f1_thr
})

print(f"✅ {name} | Argmax ACC={acc_arg:.4f} F1W={f1_arg:.4f}")
print(f"✅ {name} | Best t={best_t:.2f} -> TEST ACC={acc_thr:.4f} F1W={f1_thr:.4f}")
# Out:
# ======================================================================
# 🚀 Training: EfficientNetV2B3
# ======================================================================
# 🧩 Stage 1: warmup (frozen backbone)
# Epoch 1/20
# 348/348 [==============================] - 70s 177ms/step - loss: 0.8640 - accuracy: 0.5889 - val_loss: 0.8109 - val_accuracy: 0.5152 - lr: 2.0000e-04
# Epoch 2/20
# 348/348 [==============================] - 58s 167ms/step - loss: 0.6839 - accuracy: 0.6641 - val_loss: 0.7811 - val_accuracy: 0.5606 - lr: 2.0000e-04
# Epoch 3/20
# 348/348 [==============================] - 58s 167ms/step - loss: 0.5992 - accuracy: 0.7030 - val_loss: 0.8566 - val_accuracy: 0.5455 - lr: 2.0000e-04
# Epoch 4/20
# 348/348 [==============================] - ETA: 0s - loss: 0.5487 - accuracy: 0.7322
# Epoch 4: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-05.
#
# weighted avg       0.65      0.65      0.65       131
#
# ✅ EfficientNetV2B3 | Argmax ACC=0.6489 F1W=0.6489
# ✅ EfficientNetV2B3 | Best t=0.52 -> TEST ACC=0.6870 F1W=0.6808

# %%
# ✅ save the trained model (best)
model.save(f"{name}_erythema.keras")

# or weights only (lighter)
# model.save_weights(f"{name}_erythema.weights.h5")

import tensorflow as tf
tf.keras.backend.clear_session()
print(f"✅ Saved + cleared session for {name}")
# Out:
# ✅ Saved + cleared session for EfficientNetV2B3

# %% [markdown]
# # EfficientNetB3

# %%
name = "EfficientNetB3"
print("\n" + "="*70)
print("🚀 Training:", name)
print("="*70)

model, base, fine_tune_at = make_model(name)

print("🧩 Stage 1: warmup (frozen backbone)")
fit_model(model, epochs=20, lr=2e-4)

print("🔧 Stage 2: fine-tune (unfreeze last layers)")
base.trainable = True
for layer in base.layers[:fine_tune_at]:
    layer.trainable = False
freeze_bn(model)
fit_model(model, epochs=36, lr=6e-6)

acc_arg, f1_arg, y_true, y_pred, _ = eval_on_test(model)
show_confusion(y_true, y_pred, f"{name} Confusion Matrix (argmax)")

best_t, best_val_f1 = best_threshold_on_val(model)
acc_thr, f1_thr, y_true_t, y_pred_t = eval_threshold(model, best_t)

results.append({
    "Model": name,
    "Argmax_ACC": acc_arg,
    "Argmax_F1W": f1_arg,
    "Best_t(VAL)": best_t,
    "Test_ACC@t": acc_thr,
    "Test_F1W@t": f1_thr
})

print(f"✅ {name} | Argmax ACC={acc_arg:.4f} F1W={f1_arg:.4f}")
print(f"✅ {name} | Best t={best_t:.2f} -> TEST ACC={acc_thr:.4f} F1W={f1_thr:.4f}")
# Out:
# ======================================================================
# 🚀 Training: EfficientNetB3
# ======================================================================
# 🧩 Stage 1: warmup (frozen backbone)
# Epoch 1/20
# 348/348 [==============================] - 73s 186ms/step - loss: 0.8500 - accuracy: 0.5925 - val_loss: 0.7517 - val_accuracy: 0.6212 - lr: 2.0000e-04
# Epoch 2/20
# 348/348 [==============================] - 63s 182ms/step - loss: 0.6645 - accuracy: 0.6674 - val_loss: 0.9008 - val_accuracy: 0.4545 - lr: 2.0000e-04
# Epoch 3/20
# 348/348 [==============================] - ETA: 0s - loss: 0.5921 - accuracy: 0.7019
# Epoch 3: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-05.
# 348/348 [==============================] - 71s 205ms/step - loss: 0.5921 - accuracy: 0.7019 - val_loss: 0.8991 - val_accuracy: 0.5455 - lr: 2.0000e-04
# Epoch 4/20
# 348/348 [==============================] - 68s 195ms/step - loss: 0.5126 - accuracy: 0.7318 - val_loss: 0.8967 - val_accuracy: 0.5000 - lr: 1.0000e-04
# Epoch 5/20
# 348/348 [==============================] - ETA: 0s - loss: 0.4949 - accuracy: 0.7509
# Epoch 5: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\AppData\Local\Programs\Python\Python310\lib\json\__init__.py:238, in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     232 if cls is None:
#     233     cls = JSONEncoder
#     234 return cls(
#     235     skipkeys=skipkeys, ensure_ascii=ensure_ascii,
#     236     check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     237     separators=separators, default=default, sort_keys=sort_keys,
# --> 238     **kw).encode(obj)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\json\encoder.py:199, in JSONEncoder.encode(self, o)
#     195         return encode_basestring(o)
#     196 # This doesn't pass the iterator directly to ''.join() because the
#     197 # exceptions aren't as detailed.  The list call should be roughly
#     198 # equivalent to the PySequence_Fast that ''.join() would do.
# --> 199 chunks = self.iterencode(o, _one_shot=True)
#     200 if not isinstance(chunks, (list, tuple)):
#     201     chunks = list(chunks)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\json\encoder.py:257, in JSONEncoder.iterencode(self, o, _one_shot)
#     252 else:
#     253     _iterencode = _make_iterencode(
#     254         markers, self.default, _encoder, self.indent, floatstr,
#     255         self.key_separator, self.item_separator, self.sort_keys,
#     256         self.skipkeys, _one_shot)
# --> 257 return _iterencode(o, 0)
#
# TypeError: Unable to serialize [2.0896919 2.1128857 2.1081853] to JSON. Unrecognized type <class 'tensorflow.python.framework.ops.EagerTensor'>.

# %% [markdown]
# # Cell 17 — Model Comparison & Final Selection

# %%
results_df = pd.DataFrame(results).sort_values("Test_F1W@t", ascending=False).reset_index(drop=True)
display(results_df)

best = results_df.iloc[0]
print(f"\n🏆 BEST MODEL = {best['Model']} | Test_ACC@t={best['Test_ACC@t']:.4f} | Test_F1W@t={best['Test_F1W@t']:.4f} | Best_t={best['Best_t(VAL)']:.2f}")

results_df.to_csv("erythema_augtrain_cleanval_best3_results.csv", index=False)
print("✅ Saved: erythema_augtrain_cleanval_best3_results.csv")
# Out:
#               Model  Argmax_ACC  Argmax_F1W  Best_t(VAL)  Test_ACC@t  \
# 0   EfficientNetV2S    0.763359    0.766976         0.62    0.748092
# 1  EfficientNetV2B1    0.618321    0.631733         0.59    0.725191
# 2    EfficientNetB3    0.694656    0.704672         0.51    0.702290
# 3  EfficientNetV2B3    0.687023    0.693354         0.54    0.702290
# 4  EfficientNetV2B2    0.702290    0.711647         0.54    0.687023
# 5  EfficientNetV2B3    0.648855    0.648855         0.52    0.687023
#
#    Test_F1W@t
# 0    0.738061
# 1    0.712718
# 2    0.710708
# 3    0.698904
# 4    0.691808
# 5    0.680775
# 🏆 BEST MODEL = EfficientNetV2S | Test_ACC@t=0.7481 | Test_F1W@t=0.7381 | Best_t=0.62
# ✅ Saved: erythema_augtrain_cleanval_best3_results.csv

# %%
# ---------- Dataset counts + ratios ----------
n_train = len(train_df)
n_val   = len(val_df)
n_test  = len(test_df)
n_total = n_train + n_val + n_test

print("===== DATASET SUMMARY (ERYTHEMA) =====")
print(f"Train (aug): {n_train}")
print(f"Val   (clean): {n_val}")
print(f"Test  (clean): {n_test}")
print(f"Total: {n_total}")

print("\n===== SPLIT RATIO =====")
print(f"Train: {n_train/n_total:.2%}")
print(f"Val:   {n_val/n_total:.2%}")
print(f"Test:  {n_test/n_total:.2%}")

print("\n===== CLASS DISTRIBUTION =====")
print("Train:\n", train_df["answer"].value_counts())
print("Val:\n",   val_df["answer"].value_counts())
print("Test:\n",  test_df["answer"].value_counts())


# ---------- Recall computation ----------
# after you already have: y_true, y_pred from eval_on_test or eval_threshold

labels_map = {v: k for k, v in train_gen.class_indices.items()}
print("\nClass indices:", train_gen.class_indices)

# find which index is "Existent"
if "Existent" in train_gen.class_indices:
    ex_idx = train_gen.class_indices["Existent"]
else:
    ex_idx = 1  # fallback

# Confusion matrix (order: [0,1] by default)
cm = confusion_matrix(y_true, y_pred)
print("\n===== CONFUSION MATRIX =====")
print(cm)

# Recall for Existent = TP / (TP + FN)
# TP is cm[ex_idx, ex_idx]
# FN is sum of row ex_idx except TP -> cm[ex_idx, 1-ex_idx] (binary)
tp = cm[ex_idx, ex_idx]
fn = cm[ex_idx, :].sum() - tp
recall_existent = tp / (tp + fn + 1e-9)

print("\n===== RECALL =====")
print(f"Recall (Existent) = {recall_existent:.4f}")

# Full report includes recall for each class
print("\n===== CLASSIFICATION REPORT =====")
target_names = [labels_map[i] for i in range(len(labels_map))]
print(classification_report(y_true, y_pred, target_names=target_names, digits=4))
